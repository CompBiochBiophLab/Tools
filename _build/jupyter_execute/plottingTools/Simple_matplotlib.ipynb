# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %matplotlib inline

# %%
# let us start by creating some 2D data
x = np.random.random(20)*10
x = np.sort(x)
y = np.random.random(len(x))

print("Data array:")
print(x,y)
# Out:
# Data array:
# [0.21887235 0.75189318 0.83970676 1.19655335 1.63002241 2.3624821
#  3.1865696  3.8411     4.67270598 4.91739049 5.6718026  5.82591724
#  6.09288937 6.99331288 7.08093415 7.10644109 7.26094299 8.85388432
#  8.98230449 9.05241215] [0.89190506 0.80452533 0.56289478 0.71493179 0.9699214  0.08640732
#  0.35039331 0.6580657  0.65769864 0.59291693 0.78092969 0.34811837
#  0.41420271 0.67258128 0.1314209  0.36852414 0.13148745 0.21693268
#  0.7500242  0.79363328]

# %%
# 
print(x,y)
plt.plot(x,y)
plt.show()
# Out:
# [0.21887235 0.75189318 0.83970676 1.19655335 1.63002241 2.3624821
#  3.1865696  3.8411     4.67270598 4.91739049 5.6718026  5.82591724
#  6.09288937 6.99331288 7.08093415 7.10644109 7.26094299 8.85388432
#  8.98230449 9.05241215] [0.89190506 0.80452533 0.56289478 0.71493179 0.9699214  0.08640732
#  0.35039331 0.6580657  0.65769864 0.59291693 0.78092969 0.34811837
#  0.41420271 0.67258128 0.1314209  0.36852414 0.13148745 0.21693268
#  0.7500242  0.79363328]
